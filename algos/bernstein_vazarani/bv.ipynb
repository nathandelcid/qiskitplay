# %% [markdown]
# # Bernstein Vazarani (Restricted Deutsch-Jozsa)
#
# ## Problem Statement
#
# Given an oracle $f : \{0,1\}^n \rightarrow \{0,1\}$, where $f(x) = s \cdot x \pmod{2}$ for a hidden string $s \in \{0,1\}^n$, find the secret string $s$
